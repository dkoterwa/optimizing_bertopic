# %%
import glob
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("max_colwidth", 100)
sns.set(rc={"figure.figsize": (30, 14)})

# %%
files_list = glob.glob("./results/20newsgroups/*.json")
dfs = []
for f in files_list:
    embedding_retrieval_type = "_".join(f.split("_")[3:-1]) + "_pooling"
    df = pd.read_json(f)
    df["embedding_retrieval_type"] = embedding_retrieval_type
    dfs.append(df)

# %%
full_results = pd.concat(dfs)

# %%
keys_to_extract = ["embedding_model", "nr_topics", "min_topic_size"]
for key in keys_to_extract:
    full_results[key] = full_results["Params"].apply(lambda x: x.get(key, None))
full_results.drop("Params", axis=1, inplace=True)

# %%
keys_to_extract = ["npmi", "diversity"]
for key in keys_to_extract:
    full_results[key] = full_results["Scores"].apply(lambda x: x.get(key, None))
full_results.drop("Scores", axis=1, inplace=True)

# %%
results_grouped = full_results.groupby(
    [full_results["embedding_retrieval_type"], full_results["nr_topics"]], as_index=False
)[["nr_topics", "npmi", "diversity", "Computation Time"]].mean()

# %%
def rename_embedding_type(name):
    # Split the name into parts
    parts = name.split("_")

    # Define the new names for each part
    new_name_parts = {
        "concat": "Concat",
        "sum": "Sum",
        "last": "Last",
        "second": "Second",
        "all": "All",
        "four": "Four",
        "layers": "Layers",
        "layer": "Layer",
        "output": "Output",
        "hidden": "Hidden",
    }

    # Determine the pooling type and place it in parentheses
    pooling = parts[-2].upper() if parts[-2] == "cls" else parts[-2].capitalize()
    pooling_type = f"({pooling} Pooling)"

    # Check for 'embedding_layer' to include "Embedding Layer" in the new name
    if "_".join(parts[:2]) == "embedding_layer":
        new_name = "Embedding Layer " + " ".join(
            new_name_parts.get(part, part.capitalize()) for part in parts[2:-2]
        )
    else:
        new_name = " ".join(new_name_parts.get(part, part.capitalize()) for part in parts[1:-2])

    # Add the pooling type
    new_name += " " + pooling_type

    # Remove extra spaces and return
    return " ".join(new_name.split())

# %%
results_grouped["embedding_retrieval_type"] = [rename_embedding_type(name) for name in results_grouped["embedding_retrieval_type"]]

# %%
results_sorted_npmi = (
    results_grouped.groupby("embedding_retrieval_type")
    .mean("npmi")
    .reset_index()
    .sort_values("npmi", ascending=False)
)
top_categories_npmi = results_sorted_npmi.head(5)["embedding_retrieval_type"].tolist()

# %%
results_sorted_npmi
# Out:
#                   embedding_retrieval_type  nr_topics      npmi  diversity  \
# 16      Sum Last Four Layers (Max Pooling)       30.0  0.178811   1.000000
# 17     Sum Last Four Layers (Mean Pooling)       30.0  0.107854   0.900000
# 10         Second Last Layer (Max Pooling)       30.0  0.085372   0.900000
# 8         Last Hidden Layer (Mean Pooling)       30.0  0.076762   0.762757
# 7          Last Hidden Layer (Max Pooling)       30.0  0.074923   0.787346
# 2   Concat Last Four Layers (Mean Pooling)       30.0  0.065413   0.950000
# 11        Second Last Layer (Mean Pooling)       30.0  0.062172   0.732378
# 1    Concat Last Four Layers (Max Pooling)       30.0  0.053422   0.767123
# 14           Sum All Layers (Mean Pooling)       30.0  0.049815   0.799382
# 15      Sum Last Four Layers (CLS Pooling)       30.0  0.044715   0.751543
# 12            Sum All Layers (CLS Pooling)       30.0  0.044093   0.775680
# 4     Embedding Layer Output (Max Pooling)       30.0  0.042881   0.900000
# 0    Concat Last Four Layers (CLS Pooling)       30.0  0.039354   0.786151
# 13            Sum All Layers (Max Pooling)       30.0  0.037019   0.815217
# 6          Last Hidden Layer (CLS Pooling)       30.0  0.036320   0.747407
# 5    Embedding Layer Output (Mean Pooling)       30.0  0.017349   0.807614
# 9          Second Last Layer (CLS Pooling)       30.0 -0.009111   0.747926
# 3     Embedding Layer Output (CLS Pooling)       30.0 -0.026346   0.778573
#
#     Computation Time
# 16         22.911211
# 17         20.877208
# 10         23.298466
# 8          21.112427
# 7          22.397945
# 2          25.433574
# 11         22.412572
# 1          30.815747
# 14         21.896338
# 15         21.462194
# 12         21.661438
# 4          24.006781
# 0          27.525573
# 13         24.534819
# 6          22.018144
# 5          24.110735
# 9          23.067483
# 3          40.541092

# %%
results_sorted_diversity = (
    results_grouped.groupby("embedding_retrieval_type")
    .mean("diversity")
    .reset_index()
    .sort_values("diversity", ascending=False)
)
#results_sorted_diversity = results_sorted_diversity[results_sorted_diversity["embedding_retrieval_type"] != "Last Hidden Layer (CLS Pooling)"]
top_categories_diversity = results_sorted_diversity.head(5)["embedding_retrieval_type"].tolist()

# %%
results_grouped
# Out:
#                  embedding_retrieval_type  nr_topics      npmi  diversity  \
# 0   Concat Last Four Layers (CLS Pooling)       10.0  0.034399   0.855556
# 1   Concat Last Four Layers (CLS Pooling)       20.0  0.030948   0.826316
# 2   Concat Last Four Layers (CLS Pooling)       30.0  0.030106   0.793103
# 3   Concat Last Four Layers (CLS Pooling)       40.0  0.042818   0.733333
# 4   Concat Last Four Layers (CLS Pooling)       50.0  0.058500   0.722449
# ..                                    ...        ...       ...        ...
# 85    Sum Last Four Layers (Mean Pooling)       10.0  0.107854   0.900000
# 86    Sum Last Four Layers (Mean Pooling)       20.0  0.107854   0.900000
# 87    Sum Last Four Layers (Mean Pooling)       30.0  0.107854   0.900000
# 88    Sum Last Four Layers (Mean Pooling)       40.0  0.107854   0.900000
# 89    Sum Last Four Layers (Mean Pooling)       50.0  0.107854   0.900000
#
#     Computation Time
# 0          27.296668
# 1          27.242093
# 2          27.543518
# 3          27.877574
# 4          27.668013
# ..               ...
# 85         20.842796
# 86         21.467620
# 87         20.858086
# 88         20.748775
# 89         20.468763
#
# [80 rows x 5 columns]

# %%
top_categories_diversity
# Out:
# ['Sum Last Four Layers (Max Pooling)',
#  'Concat Last Four Layers (Mean Pooling)',
#  'Sum Last Four Layers (Mean Pooling)',
#  'Second Last Layer (Max Pooling)',
#  'Embedding Layer Output (Max Pooling)']

# %%
default_setting = results_grouped[
    results_grouped["embedding_retrieval_type"] == "Last Hidden Layer (Mean Pooling)"
]

results_grouped = results_grouped[
    results_grouped["embedding_retrieval_type"] != "Last Hidden Layer (Mean Pooling)"
]

# %%
fig, ax = plt.subplots()
sns.lineplot(
    data=results_grouped,
    x="nr_topics",
    y="npmi",
    style="embedding_retrieval_type",
    hue="embedding_retrieval_type",
    alpha=0.2,
    marker="o",
    ax=ax,
)
sns.lineplot(
    data=results_grouped[results_grouped["embedding_retrieval_type"].isin(top_categories_npmi)],
    x="nr_topics",
    y="npmi",
    style="embedding_retrieval_type",
    hue="embedding_retrieval_type",
    alpha=1,
    marker="o",
    ax=ax,
)

sns.lineplot(
    data=default_setting,
    x="nr_topics",
    y="npmi",
    style="embedding_retrieval_type",
    color="dimgrey",
    alpha=1,
    marker="o",
    ax=ax,
)
plt.xlabel("Number of topics")
plt.ylabel("Value of npmi")
plt.title("Value of Topic Coherence (npmi) for various types of embeddings", size=25)

line = ax.lines[-2]
x_data = line.get_xdata()
y_data = line.get_ydata()
x_to_annotate = x_data[-1]
y_to_annotate = y_data[-1]

ax.annotate(
    "Default BERTopic setting",
    xy=(x_to_annotate, y_to_annotate),
    xytext=(x_to_annotate + 3, y_to_annotate),
    arrowprops=dict(facecolor="black", shrink=0.05, width=2),
)

ax.legend(loc="lower right", bbox_to_anchor=(1.15, 0))
plt.show()

# %%
fig, ax = plt.subplots()
sns.lineplot(
    data=results_grouped,
    x="nr_topics",
    y="diversity",
    style="embedding_retrieval_type",
    hue="embedding_retrieval_type",
    alpha=0.2,
    marker="o",
    ax=ax,
)
sns.lineplot(
    data=results_grouped[results_grouped["embedding_retrieval_type"].isin(top_categories_diversity)],
    x="nr_topics",
    y="diversity",
    style="embedding_retrieval_type",
    hue="embedding_retrieval_type",
    alpha=1,
    marker="o",
    ax=ax,
)

sns.lineplot(
    data=default_setting,
    x="nr_topics",
    y="diversity",
    style="embedding_retrieval_type",
    color="dimgrey",
    alpha=1,
    marker="o",
    ax=ax,
)
plt.xlabel("Number of topics")
plt.ylabel("Value of diversity")
plt.title("Value of Topic Diversity for various types of embeddings", size=25)

line = ax.lines[-2]
x_data = line.get_xdata()
y_data = line.get_ydata()
x_to_annotate = x_data[-1]
y_to_annotate = y_data[-1]

ax.annotate(
    "Default BERTopic setting",
    xy=(x_to_annotate, y_to_annotate),
    xytext=(x_to_annotate + 0.8, y_to_annotate-0.08),
    arrowprops=dict(facecolor="black", shrink=0.05, width=2),
)

ax.legend(loc="lower right", bbox_to_anchor=(1.15, 0))
plt.show()
